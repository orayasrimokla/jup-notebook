# %% [markdown]
# # Me trying to add stuff

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pandas import Series, DataFrame



pd.read_table('http://bit.ly/chiporders')
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
wrkpls = pd.read_csv("file:///Users/orayasrim/Downloads/Raw%20Tensile%20Data/15%20deg/bar%201.csv", skiprows=4)
wrkpls
# Out:
#                     Time (sec)      Load (Lbf)   Stress (psi)   Strain (in)  \
# 0                        0.000           1.006           36.0        0.0001
# 1                        0.020           1.338           48.0        0.0000
# 2                        0.040           1.371           49.0        0.0000
# 3                        0.060           1.371           49.0        0.0000
# 4                        0.080           1.385           50.0        0.0000
# 5                        0.100           1.355           48.0        0.0000
# 6                        0.120           1.324           47.0        0.0000
# 7                        0.140           1.328           48.0        0.0000
# 8                        0.160           1.334           48.0        0.0000
# 9                        0.180           1.323           47.0        0.0000
# 10                       0.200           1.260           45.0        0.0000
# ...

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("bzS39oghcnY")

# %%
data = pd.read_csv("file:///Users/orayasrim/Downloads/Raw%20Tensile%20Data/15%20deg/bar%201.csv", skiprows=4, names=('Time','Load','Stress', 'Strain', 'Position', 'Cycle') )

dataNew = data.iloc[:,1].head(20)
#displays col 1 and 2


plt.plot(dataNew)

#plot(kind=hist, bin=100)

# %%
Test2 = pd.read_csv("file:///Users/orayasrim/Downloads/Raw%20Tensile%20Data/15%20deg/bar%201.csv", skiprows=5)
plt.plot(Test2[2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-a3a09f205269> in <module>()
# ...
