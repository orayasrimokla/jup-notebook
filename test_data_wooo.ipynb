# %% [markdown]
# # Me trying to add stuff

# %%
import pandas as pd
pd.read_table('http://bit.ly/chiporders')
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
wrkpls = pd.read_csv("file:///Users/orayasrim/Downloads/Raw%20Tensile%20Data/15%20deg/bar%201.csv", skiprows=5)
wrkpls
# Out:
#                          0.000           1.006      36   0.0001   0.0003    1
# 0                        0.020           1.338    48.0   0.0000   0.0001  1.0
# 1                        0.040           1.371    49.0   0.0000   0.0000  1.0
# 2                        0.060           1.371    49.0   0.0000   0.0000  1.0
# 3                        0.080           1.385    50.0   0.0000   0.0000  1.0
# 4                        0.100           1.355    48.0   0.0000   0.0000  1.0
# 5                        0.120           1.324    47.0   0.0000   0.0000  1.0
# 6                        0.140           1.328    48.0   0.0000   0.0000  1.0
# 7                        0.160           1.334    48.0   0.0000   0.0000  1.0
# 8                        0.180           1.323    47.0   0.0000   0.0000  1.0
# 9                        0.200           1.260    45.0   0.0000   0.0000  1.0
# 10                       0.220           1.205    43.0   0.0000   0.0000  1.0
# ...
